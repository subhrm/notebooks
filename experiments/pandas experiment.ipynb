# %%
import pandas as pd

# %%
df = pd.DataFrame({'col1': [1, 2, 5],
                 'col2': [0.5, 0.75, 0.8]},)
df
# Out:
#    col1  col2
# 0     1  0.50
# 1     2  0.75
# 2     5  0.80

# %%
df.to_dict()
# Out:
# {'col1': {'row1': 1, 'row2': 2}, 'col2': {'row1': 0.5, 'row2': 0.75}}

# %%
df.to_dict(orient='list')
# Out:
# {'col1': [1, 2], 'col2': [0.5, 0.75]}
