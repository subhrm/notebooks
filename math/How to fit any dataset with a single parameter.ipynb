# %% [markdown]
# ## How to fit any dataset with a single parameter
#
# The paper [https://arxiv.org/pdf/1904.12320.pdf](https://arxiv.org/pdf/1904.12320.pdf)

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# ### The Formula
# ![image.png](data:image/png;base64,...)

# %%
x = np.linspace(-2,2,5000)

# %% [markdown]
# ### Some examples
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Let's try the elephant

# %%
x = np.linspace(0,1500,10000)
alpha = 0.46340600480066
f = np.arcsin(np.sqrt(alpha))
tao = 0.01
y = np.sin( np.power(2, x*tao) * f ) ** 2
plt.scatter(x,y, 1)
