# %%
import tensorflow as tf 
import numpy as np
import pandas as pd

print(tf.__version__)
# Out:
# 1.12.0

# %%
a = tf.constant(3.0)
b = tf.constant(4.0)
c = tf.multiply(a,b)

s = tf.Session()

# %%
s.run(c)
# Out:
# 12.0
